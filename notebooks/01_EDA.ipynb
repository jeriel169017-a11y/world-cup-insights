# %% [markdown]
# # World Cup Insights
#
# ## Exploración y análisis de datos (EDA)
#
# Este notebook presenta un análisis exploratorio de los partidos de la Copa Mundial de la FIFA utilizando las clases desarrolladas en el proyecto.
#
# **Autor:** Jeriel Fonseca

# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))

from src.ingesta.cargador_datos import CargadorDatos
from src.gestor.gestor_partidos import GestorPartidos
from src.eda.procesador_eda import ProcesadorEDA

# %%
cargador = CargadorDatos()

datos = cargador.descargar_datos()

datos_mundial = cargador.guardar_partidos_mundial(datos)

gestor = GestorPartidos(datos_mundial)

eda = ProcesadorEDA(datos_mundial)

eda.limpiar_datos()
# Out:
# Archivo guardado correctamente en: data/raw/partidos-mundial.csv
#              date      home_team      away_team  home_score  away_score  \
# 1490   1930-07-13        Belgium  United States         0.0         3.0
# 1491   1930-07-13         France         Mexico         4.0         1.0
# 1492   1930-07-14         Brazil     Yugoslavia         1.0         2.0
# 1493   1930-07-14           Peru        Romania         1.0         3.0
# 1494   1930-07-15      Argentina         France         1.0         0.0
# ...           ...            ...            ...         ...         ...
# 49498  2026-07-06  United States        Belgium         1.0         4.0
# 49499  2026-07-07      Argentina          Egypt         3.0         2.0
# 49500  2026-07-07    Switzerland       Colombia         0.0         0.0
# 49501  2026-07-09         France        Morocco         2.0         0.0
# 49502  2026-07-10          Spain        Belgium         2.0         1.0
#
#            tournament        city        country  neutral
# 1490   FIFA World Cup  Montevideo        Uruguay     True
# 1491   FIFA World Cup  Montevideo        Uruguay     True
# 1492   FIFA World Cup  Montevideo        Uruguay     True
# 1493   FIFA World Cup  Montevideo        Uruguay     True
# 1494   FIFA World Cup  Montevideo        Uruguay     True
# ...               ...         ...            ...      ...
# 49498  FIFA World Cup     Seattle  United States    False
# 49499  FIFA World Cup     Atlanta  United States     True
# 49500  FIFA World Cup   Vancouver         Canada     True
# 49501  FIFA World Cup  Foxborough  United States     True
# 49502  FIFA World Cup   Inglewood  United States     True
#
# [1062 rows x 9 columns]

# %% [markdown]
# ## Cantidad de partidos

# %%
gestor.total_partidos()
# Out:
# 1064

# %% [markdown]
# ## Columnas del conjunto de datos

# %%
gestor.listar_columnas()
# Out:
# ['date',
#  'home_team',
#  'away_team',
#  'home_score',
#  'away_score',
#  'tournament',
#  'city',
#  'country',
#  'neutral']

# %% [markdown]
# ## Datos faltantes

# %%
eda.datos_faltantes()
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %% [markdown]
# ## Resumen estadístico

# %%
eda.resumen_descriptivo()
# Out:
#         home_score   away_score
# count  1062.000000  1062.000000
# mean      1.582863     1.246704
# std       1.494636     1.286251
# min       0.000000     0.000000
# 25%       0.250000     0.000000
# 50%       1.000000     1.000000
# 75%       2.000000     2.000000
# max      10.000000     8.000000

# %% [markdown]
# ## Total de goles por partido

# %%
eda.agregar_total_goles()

eda.datos[
    [
        "home_team",
        "away_team",
        "home_score",
        "away_score",
        "total_goles"
    ]
].head()
# Out:
#       home_team      away_team  home_score  away_score  total_goles
# 1490    Belgium  United States         0.0         3.0          3.0
# 1491     France         Mexico         4.0         1.0          5.0
# 1492     Brazil     Yugoslavia         1.0         2.0          3.0
# 1493       Peru        Romania         1.0         3.0          4.0
# 1494  Argentina         France         1.0         0.0          1.0
