# %% [markdown]
# # World Cup Insights
#
# ## Visualización de datos
#
# Este notebook muestra la utilización de la clase **Visualizador** para representar gráficamente la información de los partidos de la Copa Mundial de la FIFA.
#
# **Autor:** Jeriel Fonseca

# %%
from pathlib import Path
import sys

sys.path.append(str(Path.cwd().parent))

from src.ingesta.cargador_datos import CargadorDatos
from src.visualizacion.visualizador import Visualizador

# %%
cargador = CargadorDatos()

datos = cargador.descargar_datos()

datos_mundial = cargador.guardar_partidos_mundial(datos)

visualizador = Visualizador(datos_mundial)
# Out:
# Archivo guardado correctamente en: data/raw/partidos-mundial.csv

# %% [markdown]
# ## Top 10 selecciones con mayor cantidad de partidos

# %%
visualizador.grafico_top_equipos()
# Out:
# home_team
# Brazil         119.0
# Germany        116.0
# Argentina       94.0
# Italy           83.0
# England         80.0
# France          79.0
# Spain           73.0
# Mexico          65.0
# Uruguay         62.0
# Netherlands     59.0
# Name: count, dtype: float64
